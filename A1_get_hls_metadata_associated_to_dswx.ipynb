# %%
from cmr import GranuleQuery
import datetime
from shapely.geometry import Polygon
import pandas as pd
import geopandas as gpd
from tqdm import tqdm
from osgeo import gdal
import rasterio
import concurrent.futures
import backoff
from rasterio.errors import RasterioIOError
import requests
import boto3
from rasterio.session import AWSSession
import os

# %% [markdown]
# Source: https://git.earthdata.nasa.gov/projects/LPDUR/repos/lpdaac_cloud_data_access/browse/notebooks/Topic_2__Cloud_Optimized_Data.ipynb

# %%
def get_temp_creds():
    temp_creds_url = 'https://data.lpdaac.earthdatacloud.nasa.gov/s3credentials'
    return requests.get(temp_creds_url).json()
temp_creds_req = get_temp_creds()

session = boto3.Session(aws_access_key_id=temp_creds_req['accessKeyId'], 
                        aws_secret_access_key=temp_creds_req['secretAccessKey'],
                        aws_session_token=temp_creds_req['sessionToken'],
                        region_name='us-west-2')
rio_env = rasterio.Env(AWSSession(session),
                       GDAL_DISABLE_READDIR_ON_OPEN='TRUE',
                       CPL_VSIL_CURL_ALLOWED_EXTENSIONS='tif',
                       VSI_CACHE=True,
                       region_name='us-west-2',
                       GDAL_HTTP_COOKIEFILE=os.path.expanduser('~/cookies.txt'),
                       GDAL_HTTP_COOKIEJAR=os.path.expanduser('~/cookies.txt'))
rio_env.__enter__()

# %% [markdown]
# # Constants

# %%
HLS_S30_CONCEPT_ID = 'C2021957295-LPCLOUD'
HLS_L30_CONCEPT_ID = 'C2021957657-LPCLOUD'
DSWX_CONCEPT_ID = 'C2617126679-POCLOUD'

# %% [markdown]
# # Read DSWx metadata

# %%
df_dswx = gpd.read_file('dswx_metadata_with_tags.geojson')

# %%
def hls_url_generator(hls_id: str, band='B04') -> str:
    base_url = 'https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected'
    tokens = hls_id.split('.')
    prefix = f'{tokens[0]}{tokens[1]}.020'
    return f'{base_url}/{prefix}/{hls_id}/{hls_id}.{band}.tif'

# %%
hls_id = 'HLS.L30.T32RMT.2023124T095600.v2.0'
print(hls_url_generator(hls_id))
# Out:
# https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSL30.020/HLS.L30.T32RMT.2023124T095600.v2.0/HLS.L30.T32RMT.2023124T095600.v2.0.B04.tif

# %%
urls = df_dswx.hls_dataset.map(hls_url_generator)

# %%
@backoff.on_exception(backoff.expo,
                      Exception,
                      max_tries=10)
def get_hls_tag_data(url: str) -> dict:
    with rasterio.open(url) as ds:
        t = ds.tags()
    out = {key.lower() + '_hls': val for key, val in t.items()}
    return out

# %% [markdown]
# Sequentially:

# %%
hls_tags = list(map(get_hls_tag_data, tqdm(urls[:3])))
hls_tags
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:03<00:00,  1.26s/it]
# [{'accode_hls': 'LaSRC',
#   'add_offset_hls': '0.0',
#   'area_or_point_hls': 'Area',
#   'arop_ave_xshift(meters)_hls': '0',
#   'arop_ave_yshift(meters)_hls': '0',
#   'arop_ncp_hls': '0',
#   'arop_rmse(meters)_hls': '0',
#   'arop_s2_refimg_hls': 'NONE',
#   'cloud_coverage_hls': '5',
#   'datastrip_id_hls': 'S2B_OPER_MSI_L1C_DS_2BPS_20230504T140720_S20230504T123257_N05.09',
#   'hls_processing_time_hls': '2023-05-06T08:18:05Z',
#   'horizontal_cs_code_hls': 'EPSG:32725',
#   'horizontal_cs_name_hls': 'WGS84 / UTM zone 25S',
#   'l1c_image_quality_hls': 'NONE',
#   'l1_processing_time_hls': '2023-05-04T14:22:41.440202Z',
#   'long_name_hls': 'Red',
#   'mean_sun_azimuth_angle_hls': '48.3220864006816',
#   'mean_sun_zenith_angle_hls': '30.5477928719829',
#   'mean_view_azimuth_angle_hls': '103.938965586048',
#   'mean_view_zenith_angle_hls': '8.74447582209279',
#   'msi band 01 bandpass adjustment slope and offset_hls': '0.995900, -0.000200',
#   'msi band 02 bandpass adjustment slope and offset_hls': '0.977800, -0.004000',
#   'msi band 03 bandpass adjustment slope and offset_hls': '1.007500, -0.000800',
#   'msi band 04 bandpass adjustment slope and offset_hls': '0.976100, 0.001000',
#   'msi band 11 bandpass adjustment slope and offset_hls': '1.000000, -0.000300',
#   'msi band 12 bandpass adjustment slope and offset_hls': '0.986700, 0.000400',
#   'msi band 8a bandpass adjustment slope and offset_hls': '0.996600, 0.000000',
#   'nbar_solar_zenith_hls': '31.6621002873495',
#   'ncols_hls': '3660',
#   'nrows_hls': '3660',
#   'ovr_resampling_alg_hls': 'NEAREST',
#   'processing_baseline_hls': '05.09',
#   'product_uri_hls': 'S2B_MSIL1C_20230504T123259_N0509_R109_T25MER_20230504T140720.SAFE',
#   'scale_factor_hls': '0.0001',
#   'sensing_time_hls': '2023-05-04T12:33:08.84582Z',
#   'spacecraft_name_hls': 'Sentinel-2B',
#   'spatial_coverage_hls': '59',
#   'spatial_resolution_hls': '30',
#   'tile_id_hls': 'S2B_OPER_MSI_L1C_TL_2BPS_20230504T140720_A032167_T25MER_N05.09',
#   'ulx_hls': '499980',
#   'uly_hls': '-399960',
#   '_fillvalue_hls': '-9999'},
#  {'accode_hls': 'Lasrc',
#   'add_offset_hls': '0.0',
#   'area_or_point_hls': 'Area',
#   'arop_ave_xshift(meters)_hls': '0',
#   'arop_ave_yshift(meters)_hls': '0',
#   'arop_ncp_hls': '0',
#   'arop_rmse(meters)_hls': '0',
#   'arop_s2_refimg_hls': 'NONE',
#   'cloud_coverage_hls': '13',
#   'hls_processing_time_hls': '2023-05-06T07:21:25Z',
#   'horizontal_cs_name_hls': 'UTM, WGS84, UTM ZONE 42',
#   'l1_processing_time_hls': '2023-05-04T16:04:35Z',
#   'landsat_product_id_hls': 'LC08_L1TP_207244_20230504_20230504_02_RT',
#   'landsat_scene_id_hls': 'LC82072442023124LGN00',
#   'long_name_hls': 'Red',
#   'mean_sun_azimuth_angle_hls': '264.560107823245',
#   'mean_sun_zenith_angle_hls': '72.9258968299621',
#   'mean_view_azimuth_angle_hls': '16.4119240911807',
#   'mean_view_zenith_angle_hls': '6.03167516491508',
#   'nbar_solar_zenith_hls': '66.8335586216939',
#   'ncols_hls': '3660',
#   'nrows_hls': '3660',
#   'ovr_resampling_alg_hls': 'NEAREST',
#   'processing_level_hls': 'L1TP',
#   'scale_factor_hls': '0.0001',
#   'sensing_time_hls': '2023-05-04T12:56:39.1871320Z',
#   'sensor_hls': 'OLI_TIRS',
#   'sentinel2_tileid_hls': '42XVQ',
#   'spatial_coverage_hls': '46',
#   'spatial_resolution_hls': '30',
#   'tirs_ssm_model_hls': 'PRELIMINARY',
#   'tirs_ssm_position_status_hls': 'ESTIMATED',
#   'ulx_hls': '399960',
#   'uly_hls': '9000000',
#   'usgs_software_hls': 'LPGS_16.2.0',
#   '_fillvalue_hls': '-9999'},
#  {'accode_hls': 'Lasrc',
#   'add_offset_hls': '0.0',
#   'area_or_point_hls': 'Area',
#   'arop_ave_xshift(meters)_hls': '0',
#   'arop_ave_yshift(meters)_hls': '0',
#   'arop_ncp_hls': '0',
#   'arop_rmse(meters)_hls': '0',
#   'arop_s2_refimg_hls': 'NONE',
#   'cloud_coverage_hls': '16',
#   'hls_processing_time_hls': '2023-05-06T07:16:09Z',
#   'horizontal_cs_name_hls': 'UTM, WGS84, UTM ZONE 42',
#   'l1_processing_time_hls': '2023-05-04T16:04:35Z',
#   'landsat_product_id_hls': 'LC08_L1TP_207244_20230504_20230504_02_RT',
#   'landsat_scene_id_hls': 'LC82072442023124LGN00',
#   'long_name_hls': 'Red',
#   'mean_sun_azimuth_angle_hls': '264.057858414389',
#   'mean_sun_zenith_angle_hls': '72.8473788332777',
#   'mean_view_azimuth_angle_hls': '16.2212830062955',
#   'mean_view_zenith_angle_hls': '6.15860630470203',
#   'nbar_solar_zenith_hls': '66.8246518395416',
#   'ncols_hls': '3660',
#   'nrows_hls': '3660',
#   'ovr_resampling_alg_hls': 'NEAREST',
#   'processing_level_hls': 'L1TP',
#   'scale_factor_hls': '0.0001',
#   'sensing_time_hls': '2023-05-04T12:56:39.1871320Z',
#   'sensor_hls': 'OLI_TIRS',
#   'sentinel2_tileid_hls': '41XNK',
#   'spatial_coverage_hls': '43',
#   'spatial_resolution_hls': '30',
#   'tirs_ssm_model_hls': 'PRELIMINARY',
#   'tirs_ssm_position_status_hls': 'ESTIMATED',
#   'ulx_hls': '499980',
#   'uly_hls': '9000000',
#   'usgs_software_hls': 'LPGS_16.2.0',
#   '_fillvalue_hls': '-9999'}]

# %% [markdown]
# Multithread:

# %%
n = len(urls)
with concurrent.futures.ThreadPoolExecutor(max_workers=100) as executor:
    hls_tags = list(tqdm(executor.map(get_hls_tag_data, urls[:]), total=n))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 50596/50596 [22:36<00:00, 37.29it/s]

# %%
df_hls = pd.DataFrame(hls_tags)
df_hls.head()
# Out:
#   accode_hls add_offset_hls area_or_point_hls arop_ave_xshift(meters)_hls
# 0      LaSRC            0.0              Area                           0  \
# 1      Lasrc            0.0              Area                           0
# 2      Lasrc            0.0              Area                           0
# 3      Lasrc            0.0              Area                           0
# 4      Lasrc            0.0              Area                           0
#
#   arop_ave_yshift(meters)_hls arop_ncp_hls arop_rmse(meters)_hls
# 0                           0            0                     0  \
# 1                           0            0                     0
# 2                           0            0                     0
# 3                           0            0                     0
# 4                           0            0                     0
#
#   arop_s2_refimg_hls cloud_coverage_hls
# 0               NONE                  5  \
# 1               NONE                 13
# 2               NONE                 16
# 3               NONE                  8
# 4               NONE                  3
#
#                                     datastrip_id_hls  ...  uly_hls
# 0  S2B_OPER_MSI_L1C_DS_2BPS_20230504T140720_S2023...  ...  -399960  \
# 1                                                NaN  ...  9000000
# 2                                                NaN  ...  9000000
# 3                                                NaN  ...  9100020
# 4                                                NaN  ...  9100020
#
#   _fillvalue_hls                    landsat_product_id_hls
# 0          -9999                                       NaN  \
# 1          -9999  LC08_L1TP_207244_20230504_20230504_02_RT
# 2          -9999  LC08_L1TP_207244_20230504_20230504_02_RT
# 3          -9999  LC08_L1TP_207244_20230504_20230504_02_RT
# 4          -9999  LC08_L1TP_207244_20230504_20230504_02_RT
#
#     landsat_scene_id_hls processing_level_hls sensor_hls sentinel2_tileid_hls
# 0                    NaN                  NaN        NaN                  NaN  \
# 1  LC82072442023124LGN00                 L1TP   OLI_TIRS                42XVQ
# 2  LC82072442023124LGN00                 L1TP   OLI_TIRS                41XNK
# 3  LC82072442023124LGN00                 L1TP   OLI_TIRS                42XVR
# 4  LC82072442023124LGN00                 L1TP   OLI_TIRS                40XER
#
#   tirs_ssm_model_hls tirs_ssm_position_status_hls usgs_software_hls
# 0                NaN                          NaN               NaN
# 1        PRELIMINARY                    ESTIMATED       LPGS_16.2.0
# 2        PRELIMINARY                    ESTIMATED       LPGS_16.2.0
# 3        PRELIMINARY                    ESTIMATED       LPGS_16.2.0
# 4        PRELIMINARY                    ESTIMATED       LPGS_16.2.0
#
# [5 rows x 50 columns]

# %%
df_all = pd.concat([df_dswx, df_hls], axis=1)
df_all['hls_url_B04'] = urls
df_all.head()
# Out:
#                                           granule_id
# 0  OPERA_L3_DSWx-HLS_T25MER_20230504T123259Z_2023...  \
# 1  OPERA_L3_DSWx-HLS_T42XVQ_20230504T125639Z_2023...
# 2  OPERA_L3_DSWx-HLS_T41XNK_20230504T125639Z_2023...
# 3  OPERA_L3_DSWx-HLS_T42XVR_20230504T125639Z_2023...
# 4  OPERA_L3_DSWx-HLS_T40XER_20230504T125639Z_2023...
#
#                       time_acquired                      time_updated
# 0  2023-05-04T12:33:08.845000+00:00  2023-05-06T16:51:17.371000+00:00  \
# 1  2023-05-04T12:56:39.187000+00:00  2023-05-06T08:15:15.550000+00:00
# 2  2023-05-04T12:56:39.187000+00:00  2023-05-06T08:15:16.575001+00:00
# 3  2023-05-04T12:56:39.187000+00:00  2023-05-08T02:12:16.707001+00:00
# 4  2023-05-04T12:56:39.187000+00:00  2023-05-08T02:13:14.809000+00:00
#
#                                         B01_WTR_link      time_acq_str
# 0  https://archive.podaac.earthdata.nasa.gov/poda...  20230504T123259Z  \
# 1  https://archive.podaac.earthdata.nasa.gov/poda...  20230504T125639Z
# 2  https://archive.podaac.earthdata.nasa.gov/poda...  20230504T125639Z
# 3  https://archive.podaac.earthdata.nasa.gov/poda...  20230504T125639Z
# 4  https://archive.podaac.earthdata.nasa.gov/poda...  20230504T125639Z
#
#   mgrs_tile_id accode aerosol_class_remapping_enabled
# 0       T25MER  LaSRC                            TRUE  \
# 1       T42XVQ  Lasrc                            TRUE
# 2       T41XNK  Lasrc                            TRUE
# 3       T42XVR  Lasrc                            TRUE
# 4       T40XER  Lasrc                            TRUE
#
#   aerosol_not_water_to_high_conf_water_fmask_values
# 0                                        224,160,96  \
# 1                                        224,160,96
# 2                                        224,160,96
# 3                                        224,160,96
# 4                                        224,160,96
#
#   aerosol_partial_surface_aggressive_to_high_conf_water_fmask_values  ...
# 0                                 224,192,160,128,96                  ...  \
# 1                                 224,192,160,128,96                  ...
# 2                                 224,192,160,128,96                  ...
# 3                                 224,192,160,128,96                  ...
# 4                                 224,192,160,128,96                  ...
#
#   _fillvalue_hls                    landsat_product_id_hls
# 0          -9999                                       NaN  \
# 1          -9999  LC08_L1TP_207244_20230504_20230504_02_RT
# 2          -9999  LC08_L1TP_207244_20230504_20230504_02_RT
# 3          -9999  LC08_L1TP_207244_20230504_20230504_02_RT
# 4          -9999  LC08_L1TP_207244_20230504_20230504_02_RT
#
#     landsat_scene_id_hls processing_level_hls sensor_hls sentinel2_tileid_hls
# 0                    NaN                  NaN        NaN                  NaN  \
# 1  LC82072442023124LGN00                 L1TP   OLI_TIRS                42XVQ
# 2  LC82072442023124LGN00                 L1TP   OLI_TIRS                41XNK
# 3  LC82072442023124LGN00                 L1TP   OLI_TIRS                42XVR
# 4  LC82072442023124LGN00                 L1TP   OLI_TIRS                40XER
#
#   tirs_ssm_model_hls tirs_ssm_position_status_hls usgs_software_hls
# 0                NaN                          NaN               NaN  \
# 1        PRELIMINARY                    ESTIMATED       LPGS_16.2.0
# 2        PRELIMINARY                    ESTIMATED       LPGS_16.2.0
# 3        PRELIMINARY                    ESTIMATED       LPGS_16.2.0
# 4        PRELIMINARY                    ESTIMATED       LPGS_16.2.0
#
#                                          hls_url_B04
# 0  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 1  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 2  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 3  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
# 4  https://data.lpdaac.earthdatacloud.nasa.gov/lp...
#
# [5 rows x 102 columns]

# %%
df_all.to_file('dswx_metadata_linked_with_hls.geojson', driver='GeoJSON')
